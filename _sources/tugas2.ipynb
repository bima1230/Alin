# %% [markdown]
# # Aljabar matrik
# tidak mengerjakan tidak boleh masuk
# - berikan penjelasan tentang apa itu matrik
# - operasi matrik
# - penjumlahan, perkalian, pengurangan, transpose matrik
# - buat program untuk mengalikan matrik a dan b5m

# %%
import numpy as np
import sympy as sy

# %%
a = np.array([[1,3,4],[2,1,3],[4,6,4]])
b = np.array([[5,1,5],[4,2,4],[8,2,8]])
c = np.array([[2,8],[8,3],[5,4]])
d = np.array([[3,6,9],[2,4,6],[5,1,7]])
e = a + b
f = 2*a
g = a @ c
h = b @ c
i = a @ h
j = a @ b
k = j @ c

print (k.shape)
# Out:
# (3, 2)

# %%
a = np.array([[1,3,4],[2,1,3],[4,6,4]])
b = np.array([[5,1,5],[4,2,4],[8,2,8]])
c = np.array([[2,8],[8,3],[5,4]])
d = np.array([[3,6,9],[2,4,6],[5,1,7]])
#cek hasil sama atau tidak
h = b @ c
i = a @ h
j = a @ b
k = j @ c

print (i)
print (k)
# Out:
# [[463 633]
#  [346 486]
#  [724 984]]
# [[463 633]
#  [346 486]
#  [724 984]]

# %%
a = np.array([[1,3,4],[2,1,3],[4,6,4]])
b = np.array([[5,1,5],[4,2,4],[8,2,8]])
c = np.array([[2,8],[8,3],[5,4]])
d = np.array([[3,6,9],[2,4,6],[5,1,7]])
ctrans = c.transpose()
cova = ctrans@c
cova.shape
#cek
covb = c @ ctrans
covb.shape
# Out:
# (3, 3)
